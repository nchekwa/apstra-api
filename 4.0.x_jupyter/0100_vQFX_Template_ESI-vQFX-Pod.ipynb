# %% [markdown]
# # 0100 Create AOS Templates

# %% [markdown]
# Load AOS Class + get inventory trom 0000

# %%
import json
from pprint import pprint 
from Apstra import Apstra
# %store -r inventory
print(inventory)
aos_server = Apstra(inventory)
# Out:
# {'aos_server': {'username': 'admin', 'password': 'admin', 'host': '10.10.10.4', 'port': 443, 'token': 'eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJ1c2VybmFtZSI6ImFkbWluIiwiY3JlYXRlZF9hdCI6IjIwMjEtMTItMjhUMTQ6MTE6MjIuMjY3ODY0IiwidXNlcl9zZXNzaW9uIjoiZjk1MDg4MzctYWY4MC00NmFiLWJlNzEtNTcxODZmNGQxZjk4IiwiZXhwIjoxNjQwNzg3MDgyfQ.L1tFafX80s0OeTGjBjHYJbEl0SmZHltReQqJ32D2wdExzWqCPNg2yPqhVL2wPvrbq31uCDXRnf_bx_OAtXxdsw'}}

# %% [markdown]
# ## 0100A - Design -> Template -> ESI vQFX Pod
# ![GUI](img/0100A.png)

# %%
templates_url = "/api/design/templates"

f = open('json/0100A_design_templates_ESI-vQFX-Pod.json')
templates_esi_vqfx_pod = json.load(f)

resp = aos_server.http_post(templates_url, templates_esi_vqfx_pod, expected=201)
# Out:
# =>= POST /api/design/templates
# =>= DATA:
# {'asn_allocation_policy': {'spine_asn_scheme': 'single'},
#  'capability': 'pod',
#  'dhcp_service_intent': {'active': True},
#  'display_name': 'ESI vQFX Pod',
#  'external_routing_policy': {'aggregate_prefixes': [],
#                              'expect_default_ipv4_route': True,
#                              'expect_default_ipv6_route': True,
#                              'export_policy': {'l2edge_subnets': True,
#                                                'l3edge_server_links': True,
#                                                'loopbacks': True,
#                                                'spine_leaf_links': True,
#                                                'static_routes': False},
#                              'extra_export_routes': [],
#                              'extra_import_routes': [],
#                              'import_policy': 'default_only',
# ...

# %% [markdown]
# ## 0100B - Design -> Template -> DC vQFX 5-Stage
# ![GUI](img/0100B.png)

# %%
templates_url = "/api/design/templates"

f = open('json/0100B_design_templates_DC_vQFX_5-Stage.json')
templates_esi_vqfx_5stage = json.load(f)

resp = aos_server.http_post(templates_url, templates_esi_vqfx_5stage, expected=201)
# Out:
# =>= POST /api/design/templates
# =>= DATA:
# {'capability': 'blueprint',
#  'display_name': 'DC vQFX 5-Stage',
#  'fabric_addressing_policy': {'spine_leaf_links': 'ipv4',
#                               'spine_superspine_links': 'ipv4'},
#  'id': 'DC_vQFX_5-Stage',
#  'rack_based_template_counts': [{'count': 1,
#                                  'rack_based_template_id': 'ESI_vQFX_Pod'}],
#  'rack_based_templates': [{'asn_allocation_policy': {'spine_asn_scheme': 'single'},
#                            'dhcp_service_intent': {'active': True},
#                            'display_name': 'ESI vQFX Pod',
#                            'external_routing_policy': {'aggregate_prefixes': [],
#                                                        'expect_default_ipv4_route': True,
#                                                        'expect_default_ipv6_route': True,
#                                                        'export_policy': {'l2edge_subnets': True,
# ...
